# %%
"""
#  SSS  K   K        SSS  H   H IIIII EEEEE L     DDDD  EEEEE RRRR   SSS        4   4 TTTTT H   H       RRRR   OOO   OOO  K   K IIIII EEEEE  SSS  
# S     K  K        S     H   H   I   E     L     D   D E     R   R S           4   4   T   H   H       R   R O   O O   O K  K    I   E     S     
#  SSS  KKK          SSS  HHHHH   I   EEEEE L     D   D EEEEE RRRR   SSS        44444   T   HHHHH       RRRR  O   O O   O KKK     I   EEEEE  SSS  
#     S K  K            S H   H   I   E     L     D   D E     R  R      S           4   T   H   H       R  R  O   O O   O K  K    I   E         S 
# SSSS  K   K       SSSS  H   H IIIII EEEEE LLLLL DDDD  EEEEE R   R SSSS            4   T   H   H       R   R  OOO   OOO  K   K IIIII EEEEE SSSS  

1차 팀 프로젝트 6조 HelloHome 

developer   :   박시훈(cooperear)

"""
# Out:
# '\n#  SSS  K   K        SSS  H   H IIIII EEEEE L     DDDD  EEEEE RRRR   SSS        4   4 TTTTT H   H       RRRR   OOO   OOO  K   K IIIII EEEEE  SSS  \n# S     K  K        S     H   H   I   E     L     D   D E     R   R S           4   4   T   H   H       R   R O   O O   O K  K    I   E     S     \n#  SSS  KKK          SSS  HHHHH   I   EEEEE L     D   D EEEEE RRRR   SSS        44444   T   HHHHH       RRRR  O   O O   O KKK     I   EEEEE  SSS  \n#     S K  K            S H   H   I   E     L     D   D E     R  R      S           4   T   H   H       R  R  O   O O   O K  K    I   E         S \n# SSSS  K   K       SSSS  H   H IIIII EEEEE LLLLL DDDD  EEEEE R   R SSSS            4   T   H   H       R   R  OOO   OOO  K   K IIIII EEEEE SSSS  \n\n1차 팀 프로젝트 6조 HelloHome \n\ndeveloper   :   박시훈(cooperear)\n\n'

# %%
#jupyter 전용
import os
os.getcwd()
import sys
sys.path.append('AbandonedAnimals.py')
from AbandonedAnimals import AbandonedAnimals
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
b = AbandonedAnimals()


df = b.fetch_abandoned_animals(20230731,20250730) # 1년동안의 데이터 json /// 주의: 98270개이상의 var을 검색하므로 오래걸립니다.
# Out:
# https://apis.data.go.kr/1543061/abandonmentPublicService_v2/abandonmentPublic_v2?serviceKey=jWovxlcK3oev1Weeu%2FaHCUNUMIkk%2FCnZbPnX%2BQn1dcMCl9d%2BpeGX3Dh90VhNCM59BHDljQckSEiDij1B7k0U5w%3D%3D&pageNo=1&bgnde=20230731&endde=20250730&numOfRows=1000
# 요청 중: page 1
# https://apis.data.go.kr/1543061/abandonmentPublicService_v2/abandonmentPublic_v2?serviceKey=jWovxlcK3oev1Weeu%2FaHCUNUMIkk%2FCnZbPnX%2BQn1dcMCl9d%2BpeGX3Dh90VhNCM59BHDljQckSEiDij1B7k0U5w%3D%3D&pageNo=2&bgnde=20230731&endde=20250730&numOfRows=1000
# 요청 중: page 2
# https://apis.data.go.kr/1543061/abandonmentPublicService_v2/abandonmentPublic_v2?serviceKey=jWovxlcK3oev1Weeu%2FaHCUNUMIkk%2FCnZbPnX%2BQn1dcMCl9d%2BpeGX3Dh90VhNCM59BHDljQckSEiDij1B7k0U5w%3D%3D&pageNo=3&bgnde=20230731&endde=20250730&numOfRows=1000
# 요청 중: page 3
# ...

# %%
#df2 = b.dataframe

# %%
df3 = pd.read_json('data20230731_20250730.json')

# %%
#df3.loc[:,'happenDt':'orgNm'].tail(30)

#only_happenDt_orgNm_df =  df3[['happenDt','orgNm']].copy()

#only_happenDt_orgNm_df.to_json('only_happenDt_orgNm_df.json')

# %%
#df의 값은 pandas.DataFrame
print(f'{type(df3)}')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#df의 값은 pandas.DataFrame
print(f'{type(df3)}')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
original_df.columns
# Out:
# Index(['desertionNo', 'happenDt', 'happenPlace', 'kindFullNm', 'upKindCd',
#        'upKindNm', 'kindCd', 'kindNm', 'colorCd', 'age', 'weight', 'noticeNo',
#        'noticeSdt', 'noticeEdt', 'popfile1', 'popfile2', 'processState',
#        'sexCd', 'neuterYn', 'specialMark', 'careRegNo', 'careNm', 'careTel',
#        'careAddr', 'careOwnerNm', 'orgNm', 'updTm', 'endReason',
#        'vaccinationChk', 'healthChk', 'rfidCd', 'sfeSoci', 'sfeHealth',
#        'etcBigo', 'popfile3', 'popfile4', 'popfile5', 'popfile6', 'popfile7',
#        'popfile8'],
#       dtype='object')

# %%
original_df = df3.copy()

original_df.loc[:,'happenDt':'endReason']
# Out:
#         happenDt    happenPlace    kindFullNm  upKindCd upKindNm  kindCd  \
# 0       20250730      등봉동 247-3       [개] 믹스견    417000        개     114
# 1       20250730      등봉동 247-3       [개] 믹스견    417000        개     114
# 2       20250730      등봉동 247-3       [개] 믹스견    417000        개     114
# 3       20250730        평전동 240       [개] 믹스견    417000        개     114
# 4       20250730        평전동 240       [개] 믹스견    417000        개     114
# ...          ...            ...           ...       ...      ...     ...
# 207951  20230731            광명고       [개] 믹스견    417000        개     114
# 207952  20230731            광명고       [개] 믹스견    417000        개     114
# 207953  20230731            광명고       [개] 믹스견    417000        개     114
# 207954  20230731  대림로 36-1(동작구)        [개] 푸들    417000        개     128
# 207955  20230731          합정동교회  [고양이] 한국 고양이    422400      고양이     200
#
#         kindNm colorCd              age    weight  ... neuterYn  \
# ...

# %%
original_df.columns
original_df.to_json('Full_dataframe.json')

# %%
import matplotlib.font_manager as fm
import matplotlib
import matplotlib.pyplot as plt
font_path = 'C:\\windows\\Fonts\\malgun.ttf'
font_prop = fm.FontProperties(fname=font_path).get_name()
print(font_prop)
matplotlib.rc('font', family=font_prop)
# 날짜 변환

original_df['happenDt'] = pd.to_datetime(original_df['happenDt'], format='%Y%m%d')

# orgNm 상위 5개 추출
top5_orgs = original_df['orgNm'].value_counts().nlargest(5).index
df_top = original_df[original_df['orgNm'].isin(top5_orgs)]

# 날짜별 + 지역별 count 집계
grouped = (
    df_top.groupby([df_top['happenDt'].dt.to_period('D'), 'orgNm'])
    .size()
    .reset_index(name='count')
)
grouped['happenDt'] = grouped['happenDt'].dt.to_timestamp()

# 시각화
plt.figure(figsize=(20, 10))
sns.lineplot(data=grouped, x='happenDt', y='count', hue='orgNm', marker='o')
plt.title('Top 5 지역들의 유기 동물 발생 추이')
plt.xlabel('날짜')
plt.ylabel('발생 건수')
plt.legend(title=' (orgNm)', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Malgun Gothic

# %%
#df3.loc[ :, 'happenDt':'sfeSoci'].tail(30)

# %%
# 최종적으로 json file을 반환합니다.

# %%
# Euthanasia_dead_df =  df.loc[df['processState'].str.contains('안락사',na=False),'processState'].copy()
# nature_dead_df = df.loc[df['processState'].str.contains('자연사',na=False)].copy()
# on_care_df =  df.loc[df['processState'].str.contains('보호중',na=False)].copy()

# %%
# counts =Euthanasia_dead_df.value_counts()
# print(counts)

# %%
import matplotlib.font_manager as fm
import matplotlib
import matplotlib.pyplot as plt

font_path = 'C:\\windows\\Fonts\\malgun.ttf'
font_prop = fm.FontProperties(fname=font_path).get_name()
print(font_prop)
matplotlib.rc('font', family=font_prop)


animal_counts = df2['upKindNm'].value_counts()

# Filter only '개' and '고양이'
filtered_counts = animal_counts[['개', '고양이']]

# Plotting
sns.set(style="whitegrid")
plt.figure(figsize=(6, 4))
sns.barplot(x=filtered_counts.index, y=filtered_counts.values, hue=filtered_counts.index)
plt.title("개 vs 고양이 수")
plt.ylabel("Count")
plt.xlabel("동물 종류")
plt.tight_layout()
plt.show()
# Out:
# Malgun Gothic
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) Arial.
#   plt.tight_layout()
# ...
