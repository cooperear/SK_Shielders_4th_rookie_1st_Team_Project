# %%
"""
#  SSS  K   K        SSS  H   H IIIII EEEEE L     DDDD  EEEEE RRRR   SSS        4   4 TTTTT H   H       RRRR   OOO   OOO  K   K IIIII EEEEE  SSS  
# S     K  K        S     H   H   I   E     L     D   D E     R   R S           4   4   T   H   H       R   R O   O O   O K  K    I   E     S     
#  SSS  KKK          SSS  HHHHH   I   EEEEE L     D   D EEEEE RRRR   SSS        44444   T   HHHHH       RRRR  O   O O   O KKK     I   EEEEE  SSS  
#     S K  K            S H   H   I   E     L     D   D E     R  R      S           4   T   H   H       R  R  O   O O   O K  K    I   E         S 
# SSSS  K   K       SSSS  H   H IIIII EEEEE LLLLL DDDD  EEEEE R   R SSSS            4   T   H   H       R   R  OOO   OOO  K   K IIIII EEEEE SSSS  

1차 팀 프로젝트 6조 HelloHome 

developer   :   박시훈(cooperear)

"""
# Out:
# '\n#  SSS  K   K        SSS  H   H IIIII EEEEE L     DDDD  EEEEE RRRR   SSS        4   4 TTTTT H   H       RRRR   OOO   OOO  K   K IIIII EEEEE  SSS  \n# S     K  K        S     H   H   I   E     L     D   D E     R   R S           4   4   T   H   H       R   R O   O O   O K  K    I   E     S     \n#  SSS  KKK          SSS  HHHHH   I   EEEEE L     D   D EEEEE RRRR   SSS        44444   T   HHHHH       RRRR  O   O O   O KKK     I   EEEEE  SSS  \n#     S K  K            S H   H   I   E     L     D   D E     R  R      S           4   T   H   H       R  R  O   O O   O K  K    I   E         S \n# SSSS  K   K       SSSS  H   H IIIII EEEEE LLLLL DDDD  EEEEE R   R SSSS            4   T   H   H       R   R  OOO   OOO  K   K IIIII EEEEE SSSS  \n\n1차 팀 프로젝트 6조 HelloHome \n\ndeveloper   :   박시훈(cooperear)\n\n'

# %%
#jupyter 전용
import os
os.getcwd()
import sys
sys.path.append('AbandonedAnimals.py')
from AbandonedAnimals import AbandonedAnimals
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
b = AbandonedAnimals()


df = b.fetch_abandoned_animals(20230731,20250730) # 1년동안의 데이터 json /// 주의: 98270개이상의 var을 검색하므로 오래걸립니다.
# Out:
# https://apis.data.go.kr/1543061/abandonmentPublicService_v2/abandonmentPublic_v2?serviceKey=jWovxlcK3oev1Weeu%2FaHCUNUMIkk%2FCnZbPnX%2BQn1dcMCl9d%2BpeGX3Dh90VhNCM59BHDljQckSEiDij1B7k0U5w%3D%3D&pageNo=1&bgnde=20230731&endde=20250730&numOfRows=1000
# 요청 중: page 1
# https://apis.data.go.kr/1543061/abandonmentPublicService_v2/abandonmentPublic_v2?serviceKey=jWovxlcK3oev1Weeu%2FaHCUNUMIkk%2FCnZbPnX%2BQn1dcMCl9d%2BpeGX3Dh90VhNCM59BHDljQckSEiDij1B7k0U5w%3D%3D&pageNo=2&bgnde=20230731&endde=20250730&numOfRows=1000
# 요청 중: page 2
# https://apis.data.go.kr/1543061/abandonmentPublicService_v2/abandonmentPublic_v2?serviceKey=jWovxlcK3oev1Weeu%2FaHCUNUMIkk%2FCnZbPnX%2BQn1dcMCl9d%2BpeGX3Dh90VhNCM59BHDljQckSEiDij1B7k0U5w%3D%3D&pageNo=3&bgnde=20230731&endde=20250730&numOfRows=1000
# 요청 중: page 3
# ...

# %%
#df2 = b.dataframe

# %%
df3 = pd.read_json('data20230731_20250730.json')

# %%
#df3.loc[:,'happenDt':'orgNm'].tail(30)

#only_happenDt_orgNm_df =  df3[['happenDt','orgNm']].copy()

#only_happenDt_orgNm_df.to_json('only_happenDt_orgNm_df.json')

# %%
#df의 값은 pandas.DataFrame
print(f'{type(df3)}')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#df의 값은 pandas.DataFrame
print(f'{type(df3)}')
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
original_df.columns
# Out:
# Index(['desertionNo', 'happenDt', 'happenPlace', 'kindFullNm', 'upKindCd',
#        'upKindNm', 'kindCd', 'kindNm', 'colorCd', 'age', 'weight', 'noticeNo',
#        'noticeSdt', 'noticeEdt', 'popfile1', 'popfile2', 'processState',
#        'sexCd', 'neuterYn', 'specialMark', 'careRegNo', 'careNm', 'careTel',
#        'careAddr', 'careOwnerNm', 'orgNm', 'updTm', 'endReason',
#        'vaccinationChk', 'healthChk', 'rfidCd', 'sfeSoci', 'sfeHealth',
#        'etcBigo', 'popfile3', 'popfile4', 'popfile5', 'popfile6', 'popfile7',
#        'popfile8'],
#       dtype='object')

# %%
original_df = df3.copy()

original_df.loc[:,'happenDt':'endReason']
# Out:
#         happenDt    happenPlace    kindFullNm  upKindCd upKindNm  kindCd  \
# 0       20250730      등봉동 247-3       [개] 믹스견    417000        개     114
# 1       20250730      등봉동 247-3       [개] 믹스견    417000        개     114
# 2       20250730      등봉동 247-3       [개] 믹스견    417000        개     114
# 3       20250730        평전동 240       [개] 믹스견    417000        개     114
# 4       20250730        평전동 240       [개] 믹스견    417000        개     114
# ...          ...            ...           ...       ...      ...     ...
# 207951  20230731            광명고       [개] 믹스견    417000        개     114
# 207952  20230731            광명고       [개] 믹스견    417000        개     114
# 207953  20230731            광명고       [개] 믹스견    417000        개     114
# 207954  20230731  대림로 36-1(동작구)        [개] 푸들    417000        개     128
# 207955  20230731          합정동교회  [고양이] 한국 고양이    422400      고양이     200
#
#         kindNm colorCd              age    weight  ... neuterYn  \
# ...

# %%
original_df.columns
original_df.to_json('Full_dataframe.json')

# %%
import matplotlib.font_manager as fm
import matplotlib
import matplotlib.pyplot as plt
font_path = 'C:\\windows\\Fonts\\malgun.ttf'
font_prop = fm.FontProperties(fname=font_path).get_name()
print(font_prop)
matplotlib.rc('font', family=font_prop)
# 날짜 변환

original_df['happenDt'] = pd.to_datetime(original_df['happenDt'], format='%Y%m%d')

# orgNm 상위 5개 추출
top5_orgs = original_df['orgNm'].value_counts().nlargest(5).index
df_top = original_df[original_df['orgNm'].isin(top5_orgs)]

# 날짜별 + 지역별 count 집계
grouped = (
    df_top.groupby([df_top['happenDt'].dt.to_period('D'), 'orgNm'])
    .size()
    .reset_index(name='count')
)
grouped['happenDt'] = grouped['happenDt'].dt.to_timestamp()

# 시각화
plt.figure(figsize=(20, 10))
sns.lineplot(data=grouped, x='happenDt', y='count', hue='orgNm', marker='o')
plt.title('Top 5 지역들의 보호대상 동물 발생 추이(2년)')
plt.xlabel('날짜')
plt.ylabel('발생 건수')
plt.legend(title=' (orgNm)', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Malgun Gothic

# %%
#df3.loc[ :, 'happenDt':'sfeSoci'].tail(30)

# %%
# 최종적으로 json file을 반환합니다.

# %%
# Euthanasia_dead_df =  df.loc[df['processState'].str.contains('안락사',na=False),'processState'].copy()
# nature_dead_df = df.loc[df['processState'].str.contains('자연사',na=False)].copy()
# on_care_df =  df.loc[df['processState'].str.contains('보호중',na=False)].copy()

# %%
# counts =Euthanasia_dead_df.value_counts()
# print(counts)

# %%
import matplotlib.font_manager as fm
import matplotlib
import matplotlib.pyplot as plt

font_path = 'C:\\windows\\Fonts\\malgun.ttf'
font_prop = fm.FontProperties(fname=font_path).get_name()
print(font_prop)
matplotlib.rc('font', family=font_prop)


animal_counts = df2['upKindNm'].value_counts()

# Filter only '개' and '고양이'
filtered_counts = animal_counts[['개', '고양이']]

# Plotting
sns.set(style="whitegrid")
plt.figure(figsize=(6, 4))
sns.barplot(x=filtered_counts.index, y=filtered_counts.values, hue=filtered_counts.index)
plt.title("개 vs 고양이 수")
plt.ylabel("Count")
plt.xlabel("동물 종류")
plt.tight_layout()
plt.show()
# Out:
# Malgun Gothic
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 50577 (\N{HANGUL SYLLABLE YANG}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\winds\AppData\Local\Temp\ipykernel_12748\2232741684.py:23: UserWarning: Glyph 46041 (\N{HANGUL SYLLABLE DONG}) missing from font(s) Arial.
#   plt.tight_layout()
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime


import matplotlib.font_manager as fm
import matplotlib
import matplotlib.pyplot as plt
font_path = 'C:\\windows\\Fonts\\malgun.ttf'
font_prop = fm.FontProperties(fname=font_path).get_name()
print(font_prop)
matplotlib.rc('font', family=font_prop)
# 날짜 변환

# 데이터 로드
try:
    df = pd.read_json('data20230731_20250730.json')
except FileNotFoundError:
    print("Error: data.json 파일을 찾을 수 없습니다. 파일 경로를 확인해주세요.")
    exit()

# 'happenDt'를 날짜 형식으로 변환
df['happenDt'] = pd.to_datetime(df['happenDt'], format='%Y%m%d')

print("데이터 로드 및 'happenDt' 전처리 완료.")
print("데이터 미리보기:")
print(df.head())
print(f"총 데이터 건수: {len(df)}")

# 1. 날짜별 총 유기 동물 발생 건수 추이
# 가장 기본적인 시계열 분석입니다.
print("\n1. 날짜별 총 유기 동물 발생 건수 추이")
daily_counts = df.groupby('happenDt').size().reset_index(name='count')

plt.figure(figsize=(15, 6))
sns.lineplot(x='happenDt', y='count', data=daily_counts)
plt.title('Daily Abandoned Animal Occurrences Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Occurrences')
plt.grid(True)
plt.show()
# Out:
# Malgun Gothic
# 데이터 로드 및 'happenDt' 전처리 완료.
# 데이터 미리보기:
#        desertionNo   happenDt happenPlace kindFullNm  upKindCd upKindNm  \
# 0  442424202500411 2025-07-30   등봉동 247-3    [개] 믹스견    417000        개
# 1  442424202500410 2025-07-30   등봉동 247-3    [개] 믹스견    417000        개
# 2  442424202500409 2025-07-30   등봉동 247-3    [개] 믹스견    417000        개
# 3  442424202500408 2025-07-30     평전동 240    [개] 믹스견    417000        개
# 4  442424202500407 2025-07-30     평전동 240    [개] 믹스견    417000        개
#
#    kindCd kindNm colorCd              age  ... rfidCd sfeSoci  sfeHealth  \
# 0     114    믹스견  흰색&황갈색  2025(60일미만)(년생)  ...   None    None       None
# 1     114    믹스견  흰색&황갈색  2025(60일미만)(년생)  ...   None    None       None
# 2     114    믹스견  흰색&황갈색  2025(60일미만)(년생)  ...   None    None       None
# 3     114    믹스견  흰색&황갈색  2025(60일미만)(년생)  ...   None    None       None
# 4     114    믹스견  흰색&황갈색  2025(60일미만)(년생)  ...   None    None       None
#
# ...

# %%
# 2. 'processState' (상태)별 유기 동물 발생 건수
# 특정 상태의 동물이 얼마나 되는지 확인
print("\n2. 'processState' (상태)별 유기 동물 발생 건수")
plt.figure(figsize=(12, 6))
sns.countplot(y='processState', data=df, order=df['processState'].value_counts().index, palette='viridis')
plt.title('Number of Abandoned Animals by Process State')
plt.xlabel('Number of Occurrences')
plt.ylabel('Process State')
plt.grid(axis='x')
plt.show()
# Out:
# 2. 'processState' (상태)별 유기 동물 발생 건수
# C:\Users\winds\AppData\Local\Temp\ipykernel_1300\2761460127.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='processState', data=df, order=df['processState'].value_counts().index, palette='viridis')

# %%
# 3. 'kindFullNm' (품종/종류)별 유기 동물 발생 건수 (상위 10개)
# 어떤 품종/종류의 동물이 가장 많이 유기되는지 확인
print("\n3. 'kindFullNm' (품종/종류)별 유기 동물 발생 건수 (상위 10개)")
top_kinds = df['kindFullNm'].value_counts().head(10).index
plt.figure(figsize=(12, 7))
sns.countplot(y='kindFullNm', data=df, order=top_kinds, palette='magma')
plt.title('Top 10 Abandoned Animal Kinds')
plt.xlabel('Number of Occurrences')
plt.ylabel('Kind Full Name')
plt.grid(axis='x')
plt.show()
# Out:
# 3. 'kindFullNm' (품종/종류)별 유기 동물 발생 건수 (상위 10개)
# C:\Users\winds\AppData\Local\Temp\ipykernel_21208\751006435.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='kindFullNm', data=df, order=top_kinds, palette='magma')

# %%
# 4. 'sexCd' (성별)별 유기 동물 발생 건수
print("\n4. 'sexCd' (성별)별 유기 동물 발생 건수")
plt.figure(figsize=(8, 5))
sns.countplot(x='sexCd', data=df, palette='cividis')
plt.title('Number of Abandoned Animals by Sex')
plt.xlabel('Sex Code')
plt.ylabel('Number of Occurrences')
plt.grid(axis='y')
plt.show()
# Out:
# 4. 'sexCd' (성별)별 유기 동물 발생 건수
# C:\Users\winds\AppData\Local\Temp\ipykernel_1300\907723487.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sexCd', data=df, palette='cividis')

# %%
# 5. 'neuterYn' (중성화 여부)별 유기 동물 발생 건수
print("\n5. 'neuterYn' (중성화 여부)별 유기 동물 발생 건수")
plt.figure(figsize=(8, 5))
sns.countplot(x='neuterYn', data=df, palette='plasma')
plt.title('Number of Abandoned Animals by Neutered Status')
plt.xlabel('Neutered (Y/N)')
plt.ylabel('Number of Occurrences')
plt.grid(axis='y')
plt.show()
# Out:
# 5. 'neuterYn' (중성화 여부)별 유기 동물 발생 건수
# C:\Users\winds\AppData\Local\Temp\ipykernel_1300\712100296.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='neuterYn', data=df, palette='plasma')

# %%
# 'happenDt'를 날짜 형식으로 변환
df['happenDt'] = pd.to_datetime(df['happenDt'], format='%Y%m%d')

print("데이터 로드 및 'happenDt' 전처리 완료.")
# 전체 코드가 아니므로 df.head() 및 총 데이터 건수는 생략

# 6. 월별/요일별 유기 동물 발생 추이 (날짜에서 파생)
# 계절성이나 요일별 패턴이 있는지 확인
print("\n6. 월별 유기 동물 발생 추이")
df['month'] = df['happenDt'].dt.month
monthly_counts = df.groupby('month').size().reset_index(name='count')
plt.figure(figsize=(12, 6)) # figsize를 약간 더 키웠습니다.
# FutureWarning 해결: hue='month' 추가 및 legend=False 설정
sns.barplot(x='month', y='count', data=monthly_counts, hue='month',  legend=False)
plt.title('Monthly Abandoned Animal Occurrences')
plt.xlabel('Month')
plt.ylabel('Number of Occurrences')
# xticks 수정: seaborn의 카테고리형 x축 매핑에 맞춰 ticks를 range(항목 개수)로 설정
# monthly_counts에는 1월부터 12월까지 순서대로 12개의 행이 있으므로 len(monthly_counts)는 12
plt.xticks(ticks=np.arange(len(monthly_counts)), labels=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.grid(axis='y')
plt.tight_layout() # 그래프 요소들이 잘리지 않도록 조정
plt.show()

print("\n7. 요일별 유기 동물 발생 추이")
df['day_of_week'] = df['happenDt'].dt.day_name() # 요일 이름
# 요일 순서 지정
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
daily_counts_by_week = df.groupby('day_of_week').size().reindex(day_order).reset_index(name='count')

plt.figure(figsize=(10, 6))
sns.barplot(x='day_of_week', y='count', data=daily_counts_by_week, palette='PuRd')
plt.title('Day of Week Abandoned Animal Occurrences')
plt.xlabel('Day of Week')
plt.ylabel('Number of Occurrences')
plt.grid(axis='y')
plt.show()
# Out:
# 데이터 로드 및 'happenDt' 전처리 완료.
#
# 6. 월별 유기 동물 발생 추이
# 7. 요일별 유기 동물 발생 추이
# C:\Users\winds\AppData\Local\Temp\ipykernel_17248\639412231.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day_of_week', y='count', data=daily_counts_by_week, palette='PuRd')

# %%
print("\n7. 요일별 유기 동물 발생 추이")
df['day_of_week'] = df['happenDt'].dt.day_name() # 요일 이름
# 요일 순서 지정
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
daily_counts_by_week = df.groupby('day_of_week').size().reindex(day_order).reset_index(name='count')

plt.figure(figsize=(10, 6))
sns.barplot(x='day_of_week', y='count', data=daily_counts_by_week, palette='PuRd')
plt.title('Day of Week Abandoned Animal Occurrences')
plt.xlabel('Day of Week')
plt.ylabel('Number of Occurrences')
plt.grid(axis='y')
plt.show()
# Out:
# 7. 요일별 유기 동물 발생 추이
# C:\Users\winds\AppData\Local\Temp\ipykernel_1300\1623953951.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='day_of_week', y='count', data=daily_counts_by_week, palette='PuRd')

# %%
# 8. 지역별 (orgNm) 월별 발생 건수 (히트맵)
# 특정 지역의 특정 월에 발생이 많은지 패턴 확인
print("\n8. 지역별 (orgNm) 월별 발생 건수 히트맵 (상위 10개 지역)")
# 상위 10개 지역 선정
top_orgnms = df['orgNm'].value_counts().head(10).index
df_top_orgnms = df[df['orgNm'].isin(top_orgnms)].copy()

org_month_counts = df_top_orgnms.groupby(['orgNm', 'month']).size().unstack(fill_value=0)
# 월 순서가 숫자로 되어 있어 정렬이 잘 되지만, 원하는대로 '1월', '2월' 등으로 표시하고 싶다면
# columns = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'] 형태로 변경 후 reindex 가능
plt.figure(figsize=(14, 8))
sns.heatmap(org_month_counts, cmap='YlGnBu', annot=True, fmt='d', linewidths=.5)
plt.title('Monthly Abandoned Animal Occurrences by Top 10 OrgNm')
plt.xlabel('Month')
plt.ylabel('Organization Name')
plt.show()
# Out:
# 8. 지역별 (orgNm) 월별 발생 건수 히트맵 (상위 10개 지역)

# %%
# 9. 지역별 (orgNm) 성별 발생 비율 (스택 바 차트)
print("\n9. 지역별 (orgNm) 성별 발생 비율 (상위 10개 지역)")
# 상위 10개 지역 선정
org_sex_counts = df_top_orgnms.groupby(['orgNm', 'sexCd']).size().unstack(fill_value=0)
org_sex_proportions = org_sex_counts.div(org_sex_counts.sum(axis=1), axis=0) # 비율 계산

org_sex_proportions.plot(kind='bar', stacked=True, figsize=(14, 7), cmap='Set2')
plt.title('Proportion of Abandoned Animals by Sex in Top 10 OrgNms')
plt.xlabel('Organization Name')
plt.ylabel('Proportion')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Sex Code')
plt.tight_layout()
plt.show()
# Out:
# 9. 지역별 (orgNm) 성별 발생 비율 (상위 10개 지역)
